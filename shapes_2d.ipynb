# %%
import numpy as np
import matplotlib.pyplot as plt
from utils.shapes_2d import create_shape
from utils.shapes_2d import create_plot_4x4_shapes_grid

# %%
# Define grid size and gamma for heat kernel
image_shape = (128, 128)
interp_num = 5

# %%
# Define the 4 corner shapes
f1 = create_shape("circle", image_shape) # Will be at Top-left
f2 = create_shape("parentheses", image_shape)  # Will be at Bottom-left
f3 = create_shape("plus", image_shape)  # Will be at Top-right
f4 = create_shape("star", image_shape)  # Will be at Bottom-right
# Stack the shapes into a single array
A = np.array([f1, f2, f3, f4])

# %%
gamma = 0.01  # Regularization parameter
sharpen_entropy = False
create_plot_4x4_shapes_grid(A, image_shape=image_shape, gamma=gamma, entropy_reg=None, sharpen_entropy=sharpen_entropy, save_path=f"results/4x4_shapes_grid_{gamma}_ER_{sharpen_entropy}.png")

# %%
gamma = 0.004  # Regularization parameter
sharpen_entropy = False
create_plot_4x4_shapes_grid(A, image_shape=image_shape, gamma=gamma, entropy_reg=None, sharpen_entropy=sharpen_entropy, save_path=f"results/4x4_shapes_grid_{gamma}_ER_{sharpen_entropy}.png")

# %%
gamma = 0.004  # Regularization parameter
sharpen_entropy = True
create_plot_4x4_shapes_grid(A, image_shape=image_shape, gamma=gamma, entropy_reg=None, sharpen_entropy=sharpen_entropy, save_path=f"results/4x4_shapes_grid_{gamma}_ER_{sharpen_entropy}.png")
